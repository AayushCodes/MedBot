# %% [markdown]
# # medBOT
#
# ### "Simplifying healtcare for the masses"

# %% [markdown]
# "This is the deployable version of the code and uses pre-trained models"

# %% [markdown]
# Importing Libraries

# %%
from sklearn.externals import joblib
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Importing Pretrained Models
#
# > Indented block

# %%
model_KNN=joblib.load("KNN12_disease.pkl" ) # Enter correct source address 
model_DT=joblib.load("DT_disease.pkl" )

# %% [markdown]
# ### Collecting Patient's response

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print( "Hello Friend, can you please mention the issues you have in 1(Yes)/0(No) format?")
print("Don't worry, we are working on simplifying the experience for you. Bear with us")
# Out:
# Hello Friend, can you please mention the issues you have in 1(Yes)/0(No) format?
# Don't worry, we are working on simplifying the experience for you. Bear with us

# %%
Running_Nose = int(input("Running Nose : "))
Nasal_Obstruction = int(input("Nasal Obstruction : "))
Sneezing = int(input("Sneezing : "))
Throat_Pain = int(input("Throat Pain : "))
Tiredness = int(input("Tiredness : "))
Cough = int(input("Cough : "))
Fever = int(input("Fever : "))
Malaise= int(input("Malaise : "))
Inflamed_Tonsils= int(input("Inflamed Tonsils : "))
Hoarse_Voice = int(input("Hoarse Voice : "))
Breathlessness = int(input("Breathlessness : "))
Chest_Pain = int(input("Chest Pain : "))
Restlessness= int(input("Restlessness : "))
Anxiety= int(input("Anxiety : "))
Wheezing= int(input("Wheezing : "))
Chills= int(input("Chills : "))
Body_Ache= int(input("Body Ache : "))
Appetite_Loss = int(input("Appetite Loss : "))
Lethargy = int(input("Lethargy : "))
Weight_Loss = int(input("Weight Loss : "))
Headache = int(input("Headache : "))
Memory_Loss = int(input("Memory Loss : "))
Sleeplessness = int(input("Sleeplessness : "))
Vomiting = int(input("Vomiting : "))
Nausea = int(input("Nausea : "))
Constipation = int(input("Constipation : "))
Rashes = int(input("Rashes : "))
Itching = int(input("Itching : "))
Joint_Pain = int(input("Joint Pain : "))
Swelling = int(input("Swelling : "))
Weakness = int(input("Weakness : "))
Hyper_Sweating = int(input("Hyper Sweating : "))
Swollen_Gums = int(input("Swollen Gums : "))
Weight_Gain = int(input("Weight Gain : "))
Ear_Pain = int(input("Ear Pain : "))
Body_Stiffness = int(input("Body Stiffness : "))
Temperature= int(input("Temperature : "))
# Out:
# Running Nose : 0
# Nasal Obstruction : 1
# Sneezing : 0
# Throat Pain : 0
# Tiredness : 0
# Cough : 1
# Fever : 0
# Malaise : 0
# Inflamed Tonsils : 1
# Hoarse Voice : 0
# Breathlessness : 0
# Chest Pain : 0
# Restlessness : 0
# Anxiety : 0
# Wheezing : 1
# Chills : 0
# Body Ache : 0
# Appetite Loss : 0
# Lethargy : 0
# Weight Loss : 0
# Headache : 0
# Memory Loss : 0
# Sleeplessness : 0
# Vomiting : 0
# Nausea : 0
# Constipation : 0
# Rashes : 0
# Itching : 0
# Joint Pain : 0
# Swelling : 0
# Weakness : 0
# Hyper Sweating : 0
# Swollen Gums : 0
# Weight Gain : 0
# Ear Pain : 0
# Body Stiffness : 0
# Temperature : 3

# %%
test = pd.DataFrame()
test['running nose'] = [Running_Nose]
test['nasal obstruction'] = [Nasal_Obstruction]
test['sneezing'] = [Sneezing]
test['throat pain'] = [Throat_Pain]
test['tiredness'] = [Tiredness]
test['cough'] = [Cough]
test['fever'] = [Fever]
test['malaise'] = [Malaise]
test['inflamed tonsils'] = [Inflamed_Tonsils]
test['hoarse voice'] = [Hoarse_Voice]
test['breathlessness'] = [Breathlessness]
test['chest pain'] = [Chest_Pain]
test['restlessness'] = [Restlessness]
test['anxiety'] = [Anxiety]
test['wheezing'] = [Wheezing]
test['chills'] = [Chills]
test['body ache'] = [Body_Ache]
test['appetite loss'] = [Appetite_Loss]
test['lethargy'] = [Lethargy]
test['weight loss'] = [Weight_Loss]
test['headache'] = [Headache]
test['memory loss'] = [Memory_Loss]
test['sleeplessness'] = [Sleeplessness]
test['vomiting'] = [Vomiting]
test['nausea'] = [Nausea]
test['constipation'] = [Constipation]
test['rashes'] = [Rashes]
test['itching'] = [Itching]
test['joint pain'] = [Joint_Pain]
test['swelling'] = [Swelling]
test['weakness'] = [Weakness]
test['hyper sweating'] = [Hyper_Sweating]
test['swollen gums'] = [Swollen_Gums]
test['weight gain'] = [Weight_Gain]
test['ear pain'] = [Ear_Pain]
test['body stiffness'] = [Body_Stiffness]
test['temperature'] = [Temperature]

# %%
predict_disease = model_KNN.predict(test)
print( "The patient should refer to :")
print(predict_disease)

predict_disease = model_DT.predict(test)
print( "The patient should refer to :")
print(predict_disease)
# Out:
# The patient should refer to :
# ['Physician']
# The patient should refer to :
# ['ENT']
